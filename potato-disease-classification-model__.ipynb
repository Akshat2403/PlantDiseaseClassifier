# %%
import matplotlib.pyplot as plt
import tensorflow as tf
# from tensorflow.keras import models , layers
# Out:
# 2024-09-02 10:48:47.822544: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-02 10:48:47.936230: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-02 10:48:48.074052: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-02 10:48:48.171896: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-02 10:48:48.199880: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-02 10:48:48.384979: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-02 10:48:49.936423: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
IMAGE_SIZE=256
BATCH_SIZE=32

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'PlantVillage',
    shuffle=True ,
    seed=123,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE,
)
# Out:
# Found 2152 files belonging to 3 classes.
# 2024-09-02 10:48:56.756489: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: UNKNOWN ERROR (100)

# %%
len(dataset)
# Out:
# 68

# %%
class_names=dataset.class_names

# %%
type(dataset)
# Out:
# tensorflow.python.data.ops.prefetch_op._PrefetchDataset

# %%
def divide_the_dataset(dataset,trainset=0.8,valset=0.1,testset=0.1):
    dataset=dataset.shuffle(10000,seed=12)
    train_db=dataset.take(54)
    test_db=dataset.skip(54)
    val_db=test_db.take(6)
    test_db=test_db.skip(6)
    return train_db,val_db,test_db

# %%
train_ds, val_ds, test_ds = divide_the_dataset(dataset)

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  tf.keras.layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  tf.keras.layers.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.RandomRotation(0.2),
])

# %%
train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y)).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
input_shape = (None, IMAGE_SIZE, IMAGE_SIZE, 3)
model = tf.keras.models.Sequential([
    # resize_and_rescale,
    data_augmentation,
    tf.keras.layers.Conv2D(32,3,padding='same',activation='relu'),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,3,padding='same',activation='relu'),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,3,padding='same',activation='relu'),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,3,padding='same',activation='relu'),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,3,padding='same',activation='relu'),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Conv2D(64,3,padding='same',activation='relu'),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64,activation='relu'),
    tf.keras.layers.Dense(3,activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)       │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_114 (Conv2D)             │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_114               │ (None, 128, 128, 32)   │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_115 (Conv2D)             │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_115               │ (None, 64, 64, 64)     │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_116 (Conv2D)             │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_116               │ (None, 32, 32, 64)     │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_117 (Conv2D)             │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_117               │ (None, 16, 16, 64)     │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_118 (Conv2D)             │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_118               │ (None, 8, 8, 64)       │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_119 (Conv2D)             │ (None, 8, 8, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_119               │ (None, 4, 4, 64)       │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_19 (Flatten)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 64)             │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 232,899 (909.76 KB)
#  Trainable params: 232,899 (909.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(train_ds,validation_data=val_ds,epochs=50)
# Out:
# Epoch 1/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.5084 - loss: 4.8230 - val_accuracy: 0.7760 - val_loss: 0.5763
# Epoch 2/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.7613 - loss: 0.5844 - val_accuracy: 0.7969 - val_loss: 0.5666
# Epoch 3/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.8623 - loss: 0.3464 - val_accuracy: 0.8906 - val_loss: 0.2811
# Epoch 4/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9021 - loss: 0.2509 - val_accuracy: 0.9167 - val_loss: 0.2062
# Epoch 5/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.9163 - loss: 0.2100 - val_accuracy: 0.9479 - val_loss: 0.1287
# Epoch 6/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.8952 - loss: 0.2374 - val_accuracy: 0.9010 - val_loss: 0.2512
# Epoch 7/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9312 - loss: 0.1652 - val_accuracy: 0.8802 - val_loss: 0.2741
# Epoch 8/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.9167 - loss: 0.1727 - val_accuracy: 0.9062 - val_loss: 0.3003
# Epoch 9/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.9465 - loss: 0.1445 - val_accuracy: 0.9427 - val_loss: 0.1458
# Epoch 10/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.9316 - loss: 0.1748 - val_accuracy: 0.9479 - val_loss: 0.1436
# Epoch 11/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.9473 - loss: 0.1389 - val_accuracy: 0.9219 - val_loss: 0.2677
# Epoch 12/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9351 - loss: 0.1637 - val_accuracy: 0.9479 - val_loss: 0.1347
# Epoch 13/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9548 - loss: 0.1244 - val_accuracy: 0.9688 - val_loss: 0.0905
# Epoch 14/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9514 - loss: 0.1347 - val_accuracy: 0.9635 - val_loss: 0.0836
# Epoch 15/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9760 - loss: 0.0701 - val_accuracy: 0.9948 - val_loss: 0.0338
# Epoch 16/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.9606 - loss: 0.1001 - val_accuracy: 0.9792 - val_loss: 0.0496
# Epoch 17/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.9616 - loss: 0.0900 - val_accuracy: 0.9479 - val_loss: 0.1421
# Epoch 18/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - accuracy: 0.9473 - loss: 0.1155 - val_accuracy: 0.9740 - val_loss: 0.0579
# Epoch 19/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.9642 - loss: 0.0806 - val_accuracy: 0.9583 - val_loss: 0.0947
# Epoch 20/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.9680 - loss: 0.0886 - val_accuracy: 0.9896 - val_loss: 0.0353
# Epoch 21/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.9634 - loss: 0.1181 - val_accuracy: 0.9896 - val_loss: 0.0276
# Epoch 22/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.9599 - loss: 0.1160 - val_accuracy: 0.9844 - val_loss: 0.0452
# Epoch 23/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.9776 - loss: 0.0647 - val_accuracy: 0.9844 - val_loss: 0.0275
# Epoch 24/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.9857 - loss: 0.0423 - val_accuracy: 0.9896 - val_loss: 0.0211
# Epoch 25/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.9699 - loss: 0.0823 - val_accuracy: 0.9844 - val_loss: 0.0451
# Epoch 26/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.9815 - loss: 0.0666 - val_accuracy: 0.9896 - val_loss: 0.0151
# Epoch 27/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.9721 - loss: 0.0773 - val_accuracy: 0.9688 - val_loss: 0.0641
# Epoch 28/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.9770 - loss: 0.0550 - val_accuracy: 0.9948 - val_loss: 0.0205
# Epoch 29/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.9859 - loss: 0.0407 - val_accuracy: 0.9792 - val_loss: 0.0403
# Epoch 30/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.9750 - loss: 0.0614 - val_accuracy: 0.9948 - val_loss: 0.0110
# Epoch 31/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9684 - loss: 0.0638 - val_accuracy: 0.9844 - val_loss: 0.0417
# Epoch 32/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9845 - loss: 0.0401 - val_accuracy: 0.9896 - val_loss: 0.0126
# Epoch 33/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9820 - loss: 0.0631 - val_accuracy: 0.9896 - val_loss: 0.0314
# Epoch 34/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9715 - loss: 0.0661 - val_accuracy: 0.9896 - val_loss: 0.0189
# Epoch 35/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9929 - loss: 0.0217 - val_accuracy: 0.9948 - val_loss: 0.0125
# Epoch 36/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9917 - loss: 0.0260 - val_accuracy: 0.9948 - val_loss: 0.0122
# Epoch 37/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9748 - loss: 0.0744 - val_accuracy: 0.9844 - val_loss: 0.0316
# Epoch 38/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9858 - loss: 0.0353 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 39/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9868 - loss: 0.0268 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 40/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9811 - loss: 0.0580 - val_accuracy: 0.9271 - val_loss: 0.1519
# Epoch 41/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9706 - loss: 0.0812 - val_accuracy: 0.9948 - val_loss: 0.0195
# Epoch 42/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9760 - loss: 0.0642 - val_accuracy: 0.9948 - val_loss: 0.0183
# Epoch 43/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9867 - loss: 0.0405 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 44/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9887 - loss: 0.0347 - val_accuracy: 0.9948 - val_loss: 0.0104
# Epoch 45/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9893 - loss: 0.0266 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 46/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9975 - loss: 0.0076 - val_accuracy: 0.9896 - val_loss: 0.0331
# Epoch 47/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9798 - loss: 0.0633 - val_accuracy: 0.9896 - val_loss: 0.0325
# Epoch 48/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9800 - loss: 0.0457 - val_accuracy: 0.9948 - val_loss: 0.0087
# Epoch 49/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9886 - loss: 0.0233 - val_accuracy: 0.9010 - val_loss: 0.2880
# Epoch 50/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9730 - loss: 0.1117 - val_accuracy: 0.9896 - val_loss: 0.0295

# %%
scores=model.evaluate(test_ds)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - accuracy: 0.9782 - loss: 0.0704

# %%
scores
# Out:
# [0.0806531012058258, 0.97265625]

# %%
import numpy as np
for image_batch,label_batch in test_ds.take(1):
    first_image=image_batch[0].numpy().astype('uint8')
    first_label=label_batch[0].numpy()
    
    print("first image actual label:",class_names[first_label])
    plt.imshow(first_image)
    predicted_batch=model.predict(image_batch)
    first_predicted_image=np.argmax(predicted_batch[0])
    print("first image predicted label:",class_names[first_predicted_image])
    plt.axis('off')
# Out:
# first image actual label: Potato___Late_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 795ms/step
# first image predicted label: Potato___Late_blight
# 2024-09-02 14:08:23.350056: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
def predict(model,image):
    img_array=tf.keras.utils.img_to_array(image)
    # print(img_array.shape)
    img_array=tf.expand_dims(img_array,0)
    # print(img_array.shape)
    predictions=model.predict(img_array)
    prediction_class=class_names[np.argmax(predictions[0])]
    confidence=round(100*(np.max(predictions[0])),2)
    return prediction_class,confidence

# %%
plt.figure(figsize=(13,13))
for image_batch,label_batch in test_ds.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.axis('off')
        predicted_label,confidence=predict(model,image_batch[i])
        actual_label=class_names[label_batch[i].numpy()]
        plt.title(f"Actual_label:{actual_label}\n Predicted_label:{predicted_label}\n Confidence:{confidence}")
        image=image_batch[0]
        actual_label=label_batch[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2024-09-02 14:08:31.718202: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
